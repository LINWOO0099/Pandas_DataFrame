# %% [markdown]
# <a href="https://colab.research.google.com/github/LINWOO0099/Pandas_DataFrame/blob/main/Question1_Pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data_base={
    "StudentID": [101,102,103,104,105,106,107,108,109,110],
    "Name": ["Alice","Bob","Charlie","Diana","Ethan","Fiona","George","Hannah","Ivan","Julia"],
    "Age": [20,21,19,22,20,21,23,19,22,20],
    "Marks": [88,75,92,65,78,85,70,95,60,80],
    "Grade": ["A","B","A","C","B","A","B","A","C","B"]}
df= pd.DataFrame(data_base)
newdata=df.to_csv("student_data.csv", index=False)
print("DataFrame has been saved to student_data.csv")
newdata=pd.read_csv("student_data.csv")
print(newdata)
print("print the first 3 rows of the original DataFrame:")
print(newdata.head(3))
print(newdata.describe())
print(newdata.shape)
# Out:
# DataFrame has been saved to student_data.csv
#    StudentID     Name  Age  Marks Grade
# 0        101    Alice   20     88     A
# 1        102      Bob   21     75     B
# 2        103  Charlie   19     92     A
# 3        104    Diana   22     65     C
# 4        105    Ethan   20     78     B
# 5        106    Fiona   21     85     A
# 6        107   George   23     70     B
# 7        108   Hannah   19     95     A
# 8        109     Ivan   22     60     C
# 9        110    Julia   20     80     B
# print the first 3 rows of the original DataFrame:
#    StudentID     Name  Age  Marks Grade
# 0        101    Alice   20     88     A
# 1        102      Bob   21     75     B
# 2        103  Charlie   19     92     A
#        StudentID        Age      Marks
# count   10.00000  10.000000  10.000000
# mean   105.50000  20.700000  78.800000
# std      3.02765   1.337494  11.535453
# min    101.00000  19.000000  60.000000
# 25%    103.25000  20.000000  71.250000
# ...
